# %% [markdown]
# # 文字图例尽眉目

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mpg_ggplot2.csv")

# Draw Plot
plt.figure(figsize=(13,10), dpi= 80)
sns.boxplot(x='class', y='hwy', data=df, hue='cyl')
sns.stripplot(x='class', y='hwy', data=df, color='black', size=3, jitter=1)

for i in range(len(df['class'].unique())-1):
    plt.vlines(i+.5, 10, 45, linestyles='solid', colors='gray', alpha=0.2)

# Decoration
plt.title('Box Plot of Highway Mileage by Vehicle Class', fontsize=22)
plt.legend(title='Cylinders')
plt.show()

# %% [markdown]
# ## 作业
# 1. 尝试在一张图中运用所讲过的功能，对title、text、xlable、ylabel、数学表达式、tick and ticklabel、legend进行详细的设计.
#
# 说一下个人对于设计的看法，数据可视化重点还是在数据，寻找数据之间的线索，将线索以自定义的方法呈现出来才是重点，比如seaborn中自带的lmplot可以绘制拟合区域就很棒，在复现的图中有这样的可视化才是比较好看而且高级的图
# + 注意填充、色彩、透明度、边框、点的现状颜色、线条的实虚来体现数据的关联性，色彩可以在颜色表选取用'#xxxx'这样来表示，会有更好的视觉体验
# + 调整布局以及比例来达到人肉眼的舒适度
# + 可以绘制一些箱线图，小提琴图等生僻的图给展示者别样的视觉冲击
# + 网上查到的很多花里胡哨的图，个人觉得不是全部的都适合，论文当中的图不需要花里胡哨秀画图的技术，尽可能的在一幅图中呈现出多的数据特征而又不生硬
# 现阶段没时间设计很繁琐的图，贴一个我碰到的比较齐全可以当模板用的链接。
# https://juejin.cn/post/6844903922688081933

# %% [markdown]
# 2. 阅读你可能用到文献或者相关书籍，思考自己如何才能通过学过的例子将自己认为比较好看的图给复现出来
#
# 个人觉得复现一张图的话还是使用oo模式会比较好。
# + 颜色方面可以通过取色器来进行选取，以及观察色彩与数据的关系
# + 一些label、text、legend之类的应该都是比较简单
# + 地图可视化现在也是屡见不鲜，geopandas、folium、pyecharts(这个是导出html的，一般用在前端网页比较多)等
