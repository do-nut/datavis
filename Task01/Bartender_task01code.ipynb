# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots() # 创建一个包含一个axes的figure
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]
ax.plot(x, y)

# %%
plt.plot(x, y)

# %% [markdown]
# ![269a5697ad37c63a906c47c8d0bb6c6aa59911ed.png](data:image/png;base64,...)

# %% [markdown]
# - Figure 容纳所有元素
#   - Axes 构造子图
#     - Axis 坐标轴，网格
#     - Tick 刻度

# %% [markdown]
# ### 两种绘图接口

# %%
'''
Ojbect-Oriented Style
显式创建Figures和Axes
'''
x = np.linspace(0, 2, 100) # start = 0, stop = 2, interval = 100
# returns num evenly spaced samples, calcullated over the interval [start, stop]

fig, ax = plt.subplots()
ax.plot(x, x, label = 'linear')
ax.plot(x, x**2, label = 'quadratic')
ax.plot(x, x**3, label = 'cubic')
ax.plot(x, x**0.5, label = 'root')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("Simple plot")
ax.legend() # Place a legend on the axes.
# Legend : the wording on a map or diagram explaining the symbols used

# %%
'''
pyplot自动创建fig, ax
'''
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.plot(x, x**0.5, label='root')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title('Simple Plot')
plt.legend()

# %% [markdown]
# ## 作业
# 你在工作或学习中通常何时会用到数据可视化，希望通过可视化达到什么目的

# %% [markdown]
# 1. 在数据分析中，数据可视化将数据整理成易于理解的形式，可以突出趋势和异常值，而良好的可视化效果可以更好地讲述一篇数据故事，消除数据中的干扰并突出显示有用的信息。数据可视化是形式和功能之间的微妙平衡，简单的图可能非常无聊，而复杂的图可能无法传递有效的信息。
# 2. 在深度生成模型中，数据可视化可以有效帮助我们观测生成图片的质量，在异常检测中，重构序列也需要通过可视化来直观反馈一个模型的重构误差。
# 3. 总而言之，优秀的数据可视化可以直观，高效地返回数据的内在联系，以便于操作者使用不同的方式来处理分析数据。
