# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
fig, axs = plt.subplots(2, 5, figsize=(10, 4), sharex=True, sharey=True)
fig.suptitle('样例1', size=20)
for i in range(2):
    for j in range(5):
        axs[i][j].scatter(np.random.randn(10), np.random.randn(10))
        axs[i][j].set_title('第%d行，第%d列'%(i+1,j+1))
        axs[i][j].set_xlim(-5,5)
        axs[i][j].set_ylim(-5,5)
        if i==1: axs[i][j].set_xlabel('横坐标')
        if j==0: axs[i][j].set_ylabel('纵坐标')
fig.tight_layout()

# %%
fig = plt.figure(figsize=(10, 4))
spec = fig.add_gridspec(nrows=2, ncols=5, width_ratios=[1,2,3,4,5], height_ratios=[1,3])
fig.suptitle('样例2', size=20)
for i in range(2):
    for j in range(5):
        ax = fig.add_subplot(spec[i, j])
        ax.scatter(np.random.randn(10), np.random.randn(10))
        ax.set_title('第%d行，第%d列'%(i+1,j+1))
        if i==1: ax.set_xlabel('横坐标')
        if j==0: ax.set_ylabel('纵坐标')
fig.tight_layout()

# %%
fig = plt.figure(figsize=(10, 4))
spec = fig.add_gridspec(nrows=2, ncols=6, width_ratios=[2,2.5,3,1,1.5,2], height_ratios=[1,2])
fig.suptitle('样例3', size=20)
# sub1
ax = fig.add_subplot(spec[0, :3])
ax.scatter(np.random.randn(10), np.random.randn(10))
# sub2
ax = fig.add_subplot(spec[0, 3:5])
ax.scatter(np.random.randn(10), np.random.randn(10))
# sub3
ax = fig.add_subplot(spec[:, 5])
ax.scatter(np.random.randn(10), np.random.randn(10))
# sub4
ax = fig.add_subplot(spec[1, 0])
ax.scatter(np.random.randn(10), np.random.randn(10))
# sub5
ax = fig.add_subplot(spec[1, 1:5])
ax.scatter(np.random.randn(10), np.random.randn(10))
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4,3))
ax.hist(np.random.randn(1000))
# Out:
# (array([  2.,  11.,  40., 110., 219., 276., 201., 102.,  32.,   7.]),
#  array([-3.73538582, -3.04496694, -2.35454806, -1.66412918, -0.97371031,
#         -0.28329143,  0.40712745,  1.09754633,  1.78796521,  2.47838408,
#          3.16880296]),
#  <a list of 10 Patch objects>)

# %%
fig, ax = plt.subplots(figsize=(4,3))
ax.axhline(0.5,0.2,0.8)
ax.axvline(0.5,0.2,0.8)
ax.axline([0.3,0.3],[0.7,0.7])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-44438d1c95a5> in <module>
#       2 ax.axhline(0.5,0.2,0.8)
#       3 ax.axvline(0.5,0.2,0.8)
# ----> 4 ax.axline([0.3,0.3],[0.7,0.7])
#
# AttributeError: 'AxesSubplot' object has no attribute 'axline'

# %%
fig, ax = plt.subplots(figsize=(4,3))
ax.grid(True)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
fig.suptitle('大标题', size=20)
for j in range(2):
    axs[j].plot(list('abcd'), [10**i for i in range(4)])
    if j==0:
        axs[j].set_yscale('log')
        axs[j].set_title('子标题1')
        axs[j].set_ylabel('对数坐标')
    else:
        axs[j].set_title('子标题1')
        axs[j].set_ylabel('普通坐标')
fig.tight_layout()

# %% [markdown]
# # 作业
#
# 1. 墨尔本1981年至1990年的每月温度情况

# %%
ex1 = pd.read_csv('D:\pythonlearning\MATplot\时间序列数据.csv')
ex1.head()
# Out:
#    ds      zdyd     zdgw1    zdgw2    zdgw3     zdhj1     zdhj2      zdhj  \
# 0   1  42804896  45018407  4152303  4062389  87823303  91975606  96037995
# 1   2  42058303  44077560  5431626  1727168  86135863  91567489  93294657
# 2   3  44337133  44855689  5846230   956261  89192822  95039053  95995314
# 3   4  43304268  43176498  4683543   982589  86480767  91164310  92146899
# 4   5  42982008  42812710  4927279  4505778  85794718  90721997  95227776
#
#        ywhj     gwhj1    gwhj2    gwhj3       hj1       hj2        hj       zk
# 0  40072411  45154855  4144496  4058009  85227266  89371762  93429771  2603844
# 1  39060782  44221000  5424206  1725059  83281782  88705988  90431047  2861501
# 2  41095448  44982895  5838828   952944  86078343  91917171  92870115  3121881
# 3  39903604  43303512  4675729   979159  83207116  87882845  88862005  3281465
# 4  39474949  42935994  4918853  4501856  82410943  87329796  91831653  3392201

# %%
fig, axs = plt.subplots(2, 5, figsize=(10, 4), sharex=True, sharey=True)
fig.suptitle('样例1', size=20)
for i in range(2):
    for j in range(5):
    
        axs[i][j].set_title('第%d行，第%d列'%(i+1,j+1))
        if i==1: 
            axs[i][j].plot(ex1.loc[0:11,'ds'],ex1.iloc[0:12,j+1])
            axs[i][j].set_xlim(min(ex1.loc[0:11,'ds']),max(ex1.loc[0:11,'ds']))
#            axs[i][j].set_ylim(min(ex1.iloc[0:12,j+1]),max(ex1.iloc[0:12,j+1]))
        if i==0: 
            axs[i][j].plot(ex1.loc[12:23,'ds'],ex1.iloc[12:24,j+1])
            axs[i][j].set_xlim(min(ex1.loc[12:23,'ds']),max(ex1.loc[12:23,'ds']))
#            axs[i][j].set_ylim(min(ex1.iloc[12:24,j+1]),max(ex1.iloc[12:24,j+1]))
fig.tight_layout()

# %% [markdown]
# #2. 画出数据的散点图和边际分布
#
# 用 np.random.randn(2, 150) 生成一组二维数据，使用两种非均匀子图的分割方法，做出该数据对应的散点图和边际分布图

# %%
fig, ax = plt.subplots(figsize=(4,3))
ax.hist(np.random.randn(1000))
# Out:
# (array([  7.,  26.,  70., 173., 206., 222., 165.,  86.,  37.,   8.]),
#  array([-2.99269435, -2.40127   , -1.80984564, -1.21842129, -0.62699694,
#         -0.03557258,  0.55585177,  1.14727612,  1.73870048,  2.33012483,
#          2.92154918]),
#  <a list of 10 Patch objects>)

# %%
#散点图
fig, ax = plt.subplots()
ax.scatter(np.random.randn(100), np.random.randn(100))

# %%
fig, ax = plt.subplots()
b = ax.barh(range(10),np.random.rand(10), color='#6699CC')

# %%
fig = plt.figure(figsize=(10, 4))
spec = fig.add_gridspec(nrows=2, ncols=2, width_ratios=[3,1], height_ratios=[1,3])
fig.suptitle('样例3', size=20)
# sub1
ax = fig.add_subplot(spec[0, :2])
ax.hist(np.random.randn(1000))
# sub2
ax = fig.add_subplot(spec[1, 0])
ax.scatter(np.random.randn(100), np.random.randn(100))
# sub3
ax = fig.add_subplot(spec[1, 1])
ax.barh(range(10),np.random.rand(10), color='#6699CC')
fig.tight_layout()
